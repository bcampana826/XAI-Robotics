# %%
import shap
import numpy as np
from sklearn.linear_model import LinearRegression
from lime import lime_tabular
from stable_baselines3 import PPO
import matplotlib.pyplot as plt
import gymnasium as gym

shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
env = gym.make('MountainCarContinuous-v0')
model = PPO.load("ppo_mountain.zip",env,verbose=100)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=2000000)

# Save the trained model
model.save("ppo_mountain.zip")
# Out:
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 999       |
# |    ep_rew_mean     | -0.000623 |
# | time/              |           |
# |    fps             | 2447      |
# |    iterations      | 1         |
# |    time_elapsed    | 0         |
# |    total_timesteps | 2048      |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000593   |
# | time/                   |             |
# |    fps                  | 1556        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010238464 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.01        |
# |    explained_variance   | -2.33       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0274      |
# |    n_updates            | 3930        |
# |    policy_gradient_loss | 0.00562     |
# |    std                  | 0.00162     |
# |    value_loss           | 2.77e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000623    |
# | time/                   |              |
# |    fps                  | 1408         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0056923768 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.01         |
# |    explained_variance   | -0.483       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0195      |
# |    n_updates            | 3940         |
# |    policy_gradient_loss | 0.00349      |
# |    std                  | 0.00162      |
# |    value_loss           | 1.18e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000635    |
# | time/                   |              |
# |    fps                  | 1337         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0070639225 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.01         |
# |    explained_variance   | -2.17        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -1.58e-05    |
# |    n_updates            | 3950         |
# |    policy_gradient_loss | 0.00466      |
# |    std                  | 0.00161      |
# |    value_loss           | 4.07e-08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000674   |
# | time/                   |             |
# |    fps                  | 1300        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015916128 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.02        |
# |    explained_variance   | -1.13       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0137      |
# |    n_updates            | 3960        |
# |    policy_gradient_loss | 0.00639     |
# |    std                  | 0.00159     |
# |    value_loss           | 4.91e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000684   |
# | time/                   |             |
# |    fps                  | 1270        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010946396 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.02        |
# |    explained_variance   | 0.016       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0324      |
# |    n_updates            | 3970        |
# |    policy_gradient_loss | 0.00608     |
# |    std                  | 0.0016      |
# |    value_loss           | 9.51e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000702    |
# | time/                   |              |
# |    fps                  | 1249         |
# |    iterations           | 7            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0057014157 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.03         |
# |    explained_variance   | -3.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00236     |
# |    n_updates            | 3980         |
# |    policy_gradient_loss | 0.00649      |
# |    std                  | 0.00159      |
# |    value_loss           | 5.45e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000713   |
# | time/                   |             |
# |    fps                  | 1241        |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006920983 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.03        |
# |    explained_variance   | -3.51       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00152    |
# |    n_updates            | 3990        |
# |    policy_gradient_loss | 0.00452     |
# |    std                  | 0.00159     |
# |    value_loss           | 2.44e-06    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -0.000712  |
# | time/                   |            |
# |    fps                  | 1230       |
# |    iterations           | 9          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.02322261 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.03       |
# |    explained_variance   | -3.65      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00291    |
# |    n_updates            | 4000       |
# |    policy_gradient_loss | 0.00549    |
# |    std                  | 0.00159    |
# |    value_loss           | 2.11e-06   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000711   |
# | time/                   |             |
# |    fps                  | 1221        |
# |    iterations           | 10          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016066153 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.02        |
# |    explained_variance   | -0.563      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0012     |
# |    n_updates            | 4010        |
# |    policy_gradient_loss | 0.00524     |
# |    std                  | 0.0016      |
# |    value_loss           | 1.85e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000697   |
# | time/                   |             |
# |    fps                  | 1215        |
# |    iterations           | 11          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012273652 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.02        |
# |    explained_variance   | -2.9        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0776      |
# |    n_updates            | 4020        |
# |    policy_gradient_loss | 0.00944     |
# |    std                  | 0.00159     |
# |    value_loss           | 3.11e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000678   |
# | time/                   |             |
# |    fps                  | 1212        |
# |    iterations           | 12          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011664358 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.03        |
# |    explained_variance   | -1.29       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00864    |
# |    n_updates            | 4030        |
# |    policy_gradient_loss | 0.00413     |
# |    std                  | 0.00158     |
# |    value_loss           | 2.59e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000655    |
# | time/                   |              |
# |    fps                  | 1207         |
# |    iterations           | 13           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0066415602 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.04         |
# |    explained_variance   | -0.587       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0264      |
# |    n_updates            | 4040         |
# |    policy_gradient_loss | 0.00357      |
# |    std                  | 0.00156      |
# |    value_loss           | 9.78e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000639   |
# | time/                   |             |
# |    fps                  | 1206        |
# |    iterations           | 14          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006342906 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.04        |
# |    explained_variance   | -1.53       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00391    |
# |    n_updates            | 4050        |
# |    policy_gradient_loss | 0.00255     |
# |    std                  | 0.00156     |
# |    value_loss           | 7.28e-06    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -0.000623  |
# | time/                   |            |
# |    fps                  | 1201       |
# |    iterations           | 15         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01877563 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.05       |
# |    explained_variance   | -0.947     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00097    |
# |    n_updates            | 4060       |
# |    policy_gradient_loss | 0.00823    |
# |    std                  | 0.00155    |
# |    value_loss           | 0.000555   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000608   |
# | time/                   |             |
# |    fps                  | 1199        |
# |    iterations           | 16          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009880557 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.05        |
# |    explained_variance   | -0.513      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0335      |
# |    n_updates            | 4070        |
# |    policy_gradient_loss | 0.00581     |
# |    std                  | 0.00155     |
# |    value_loss           | 2.14e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000593    |
# | time/                   |              |
# |    fps                  | 1196         |
# |    iterations           | 17           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0097950455 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.05         |
# |    explained_variance   | -2.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.006        |
# |    n_updates            | 4080         |
# |    policy_gradient_loss | 0.00559      |
# |    std                  | 0.00154      |
# |    value_loss           | 5.69e-08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000579   |
# | time/                   |             |
# |    fps                  | 1193        |
# |    iterations           | 18          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013786035 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.06        |
# |    explained_variance   | 0.056       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00434    |
# |    n_updates            | 4090        |
# |    policy_gradient_loss | 0.00748     |
# |    std                  | 0.00152     |
# |    value_loss           | 1.86e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000567   |
# | time/                   |             |
# |    fps                  | 1189        |
# |    iterations           | 19          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.020269744 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.07        |
# |    explained_variance   | -0.928      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00751     |
# |    n_updates            | 4100        |
# |    policy_gradient_loss | 0.00513     |
# |    std                  | 0.00151     |
# |    value_loss           | 1.65e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000557   |
# | time/                   |             |
# |    fps                  | 1186        |
# |    iterations           | 20          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012131073 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.08        |
# |    explained_variance   | -3.19       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00446    |
# |    n_updates            | 4110        |
# |    policy_gradient_loss | 0.0132      |
# |    std                  | 0.00151     |
# |    value_loss           | 7.77e-08    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -0.000552  |
# | time/                   |            |
# |    fps                  | 1184       |
# |    iterations           | 21         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02858194 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.08       |
# |    explained_variance   | -0.0828    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00355   |
# |    n_updates            | 4120       |
# |    policy_gradient_loss | 0.00922    |
# |    std                  | 0.00151    |
# |    value_loss           | 1.24e-08   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000547   |
# | time/                   |             |
# |    fps                  | 1184        |
# |    iterations           | 22          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012323309 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.08        |
# |    explained_variance   | -0.699      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0127      |
# |    n_updates            | 4130        |
# |    policy_gradient_loss | 0.00696     |
# |    std                  | 0.0015      |
# |    value_loss           | 1.97e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000547    |
# | time/                   |              |
# |    fps                  | 1183         |
# |    iterations           | 23           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0125293415 |
# |    clip_fraction        | 0.191        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.09         |
# |    explained_variance   | -0.00376     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00125      |
# |    n_updates            | 4140         |
# |    policy_gradient_loss | 0.00803      |
# |    std                  | 0.0015       |
# |    value_loss           | 4.71e-09     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000553    |
# | time/                   |              |
# |    fps                  | 1183         |
# |    iterations           | 24           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0063117323 |
# |    clip_fraction        | 0.169        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.09         |
# |    explained_variance   | -1.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00362      |
# |    n_updates            | 4150         |
# |    policy_gradient_loss | 0.00697      |
# |    std                  | 0.00149      |
# |    value_loss           | 1.37e-08     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -0.00055   |
# | time/                   |            |
# |    fps                  | 1182       |
# |    iterations           | 25         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01262403 |
# |    clip_fraction        | 0.237      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.08       |
# |    explained_variance   | -3.9       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00324    |
# |    n_updates            | 4160       |
# |    policy_gradient_loss | 0.0158     |
# |    std                  | 0.0015     |
# |    value_loss           | 5.6e-08    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000547   |
# | time/                   |             |
# |    fps                  | 1180        |
# |    iterations           | 26          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.022696547 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.08        |
# |    explained_variance   | -2.84       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0125     |
# |    n_updates            | 4170        |
# |    policy_gradient_loss | 0.011       |
# |    std                  | 0.0015      |
# |    value_loss           | 1.24e-08    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -0.000543  |
# | time/                   |            |
# |    fps                  | 1179       |
# |    iterations           | 27         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00426119 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.08       |
# |    explained_variance   | -1.24      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00273    |
# |    n_updates            | 4180       |
# |    policy_gradient_loss | 0.0135     |
# |    std                  | 0.0015     |
# |    value_loss           | 5.39e-09   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000546   |
# | time/                   |             |
# |    fps                  | 1178        |
# |    iterations           | 28          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.028117845 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.08        |
# |    explained_variance   | -0.916      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0139      |
# |    n_updates            | 4190        |
# |    policy_gradient_loss | 0.00882     |
# |    std                  | 0.00151     |
# |    value_loss           | 1.05e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000546   |
# | time/                   |             |
# |    fps                  | 1179        |
# |    iterations           | 29          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008139413 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.08        |
# |    explained_variance   | -0.738      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0112      |
# |    n_updates            | 4200        |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 0.00151     |
# |    value_loss           | 4.65e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000551   |
# | time/                   |             |
# |    fps                  | 1177        |
# |    iterations           | 30          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009324684 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.07        |
# |    explained_variance   | -2.12       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00834     |
# |    n_updates            | 4210        |
# |    policy_gradient_loss | 0.00642     |
# |    std                  | 0.00152     |
# |    value_loss           | 2.46e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000552   |
# | time/                   |             |
# |    fps                  | 1176        |
# |    iterations           | 31          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.012914538 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.07        |
# |    explained_variance   | -1.79       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0301      |
# |    n_updates            | 4220        |
# |    policy_gradient_loss | 0.00962     |
# |    std                  | 0.00152     |
# |    value_loss           | 3.01e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000559   |
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 32          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010497687 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.07        |
# |    explained_variance   | -0.499      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0027      |
# |    n_updates            | 4230        |
# |    policy_gradient_loss | 0.00749     |
# |    std                  | 0.00152     |
# |    value_loss           | 1.48e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000566   |
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 33          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007878673 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.07        |
# |    explained_variance   | -3.65       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0159      |
# |    n_updates            | 4240        |
# |    policy_gradient_loss | 0.00586     |
# |    std                  | 0.00152     |
# |    value_loss           | 5.22e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000571   |
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 34          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008465587 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.07        |
# |    explained_variance   | -0.6        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.014       |
# |    n_updates            | 4250        |
# |    policy_gradient_loss | 0.0078      |
# |    std                  | 0.00152     |
# |    value_loss           | 3.23e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000574    |
# | time/                   |              |
# |    fps                  | 1175         |
# |    iterations           | 35           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0042220782 |
# |    clip_fraction        | 0.164        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.06         |
# |    explained_variance   | -1.34        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00389     |
# |    n_updates            | 4260         |
# |    policy_gradient_loss | 0.00585      |
# |    std                  | 0.00154      |
# |    value_loss           | 1.32e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000575   |
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 36          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012901381 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.06        |
# |    explained_variance   | -0.904      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0222      |
# |    n_updates            | 4270        |
# |    policy_gradient_loss | 0.00592     |
# |    std                  | 0.00154     |
# |    value_loss           | 3.8e-08     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000574   |
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 37          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009998244 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.06        |
# |    explained_variance   | -3.15       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00777     |
# |    n_updates            | 4280        |
# |    policy_gradient_loss | 0.00916     |
# |    std                  | 0.00153     |
# |    value_loss           | 2.97e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000572   |
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 38          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009197291 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.07        |
# |    explained_variance   | -2.21       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 4290        |
# |    policy_gradient_loss | 0.00728     |
# |    std                  | 0.00152     |
# |    value_loss           | 5.07e-09    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000571   |
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 39          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011586176 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.07        |
# |    explained_variance   | -2.63       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0215      |
# |    n_updates            | 4300        |
# |    policy_gradient_loss | 0.007       |
# |    std                  | 0.00153     |
# |    value_loss           | 1.14e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000574    |
# | time/                   |              |
# |    fps                  | 1174         |
# |    iterations           | 40           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0051486446 |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.06         |
# |    explained_variance   | -0.824       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00797     |
# |    n_updates            | 4310         |
# |    policy_gradient_loss | 0.00918      |
# |    std                  | 0.00153      |
# |    value_loss           | 5.35e-08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000573   |
# | time/                   |             |
# |    fps                  | 1173        |
# |    iterations           | 41          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.014199219 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.06        |
# |    explained_variance   | -0.27       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0109     |
# |    n_updates            | 4320        |
# |    policy_gradient_loss | 0.00681     |
# |    std                  | 0.00153     |
# |    value_loss           | 9.54e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000573   |
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 42          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.010615284 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.06        |
# |    explained_variance   | -0.681      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00429     |
# |    n_updates            | 4330        |
# |    policy_gradient_loss | 0.00824     |
# |    std                  | 0.00153     |
# |    value_loss           | 6.84e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000577   |
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 43          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.016703155 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.06        |
# |    explained_variance   | -0.533      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0247     |
# |    n_updates            | 4340        |
# |    policy_gradient_loss | 0.00692     |
# |    std                  | 0.00155     |
# |    value_loss           | 3.37e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000578   |
# | time/                   |             |
# |    fps                  | 1173        |
# |    iterations           | 44          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.023101285 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.04        |
# |    explained_variance   | -0.451      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00359     |
# |    n_updates            | 4350        |
# |    policy_gradient_loss | 0.00649     |
# |    std                  | 0.00156     |
# |    value_loss           | 6.11e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.00058    |
# | time/                   |             |
# |    fps                  | 1173        |
# |    iterations           | 45          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008503232 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.04        |
# |    explained_variance   | -0.027      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0031     |
# |    n_updates            | 4360        |
# |    policy_gradient_loss | 0.00757     |
# |    std                  | 0.00157     |
# |    value_loss           | 1.13e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000582    |
# | time/                   |              |
# |    fps                  | 1173         |
# |    iterations           | 46           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0057160123 |
# |    clip_fraction        | 0.148        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.03         |
# |    explained_variance   | -0.0982      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0119      |
# |    n_updates            | 4370         |
# |    policy_gradient_loss | 0.00558      |
# |    std                  | 0.00158      |
# |    value_loss           | 1.65e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000584   |
# | time/                   |             |
# |    fps                  | 1173        |
# |    iterations           | 47          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010975917 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.03        |
# |    explained_variance   | -0.8        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00138    |
# |    n_updates            | 4380        |
# |    policy_gradient_loss | 0.00512     |
# |    std                  | 0.00159     |
# |    value_loss           | 1.59e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000587   |
# | time/                   |             |
# |    fps                  | 1173        |
# |    iterations           | 48          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013147255 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.02        |
# |    explained_variance   | -0.671      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00746    |
# |    n_updates            | 4390        |
# |    policy_gradient_loss | 0.00503     |
# |    std                  | 0.00159     |
# |    value_loss           | 1.04e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.00059     |
# | time/                   |              |
# |    fps                  | 1173         |
# |    iterations           | 49           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0060324017 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.03         |
# |    explained_variance   | -0.463       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0103      |
# |    n_updates            | 4400         |
# |    policy_gradient_loss | 0.00546      |
# |    std                  | 0.00158      |
# |    value_loss           | 8.67e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000593    |
# | time/                   |              |
# |    fps                  | 1173         |
# |    iterations           | 50           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0058119744 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.03         |
# |    explained_variance   | -0.226       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0117       |
# |    n_updates            | 4410         |
# |    policy_gradient_loss | 0.00773      |
# |    std                  | 0.00159      |
# |    value_loss           | 2.48e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000595   |
# | time/                   |             |
# |    fps                  | 1172        |
# |    iterations           | 51          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.007997096 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.02        |
# |    explained_variance   | -0.432      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00882    |
# |    n_updates            | 4420        |
# |    policy_gradient_loss | 0.00494     |
# |    std                  | 0.00161     |
# |    value_loss           | 3.56e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000596    |
# | time/                   |              |
# |    fps                  | 1172         |
# |    iterations           | 52           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0037994892 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.02         |
# |    explained_variance   | -0.476       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0188       |
# |    n_updates            | 4430         |
# |    policy_gradient_loss | 0.0024       |
# |    std                  | 0.0016       |
# |    value_loss           | 1.01e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000597   |
# | time/                   |             |
# |    fps                  | 1173        |
# |    iterations           | 53          |
# |    time_elapsed         | 92          |
# ...
# | train/                  |             |
# |    approx_kl            | 0.010570623 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.35        |
# |    explained_variance   | -2.61       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0107      |
# |    n_updates            | 6130        |
# |    policy_gradient_loss | 0.00654     |
# |    std                  | 0.00115     |
# |    value_loss           | 7.04e-09    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 999          |
# |    ep_rew_mean          | -0.000221    |
# | time/                   |              |
# |    fps                  | 1165         |
# |    iterations           | 223          |
# |    time_elapsed         | 391          |
# |    total_timesteps      | 456704       |
# | train/                  |              |
# |    approx_kl            | 0.0046182335 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 5.35         |
# |    explained_variance   | -0.716       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00138     |
# |    n_updates            | 6140         |
# |    policy_gradient_loss | 0.00512      |
# |    std                  | 0.00115      |
# |    value_loss           | 3.69e-09     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.00022    |
# | time/                   |             |
# |    fps                  | 1165        |
# |    iterations           | 224         |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.011467689 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.35        |
# |    explained_variance   | -0.371      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0112      |
# |    n_updates            | 6150        |
# |    policy_gradient_loss | 0.00573     |
# |    std                  | 0.00115     |
# |    value_loss           | 1.39e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000219   |
# | time/                   |             |
# |    fps                  | 1165        |
# |    iterations           | 225         |
# |    time_elapsed         | 395         |
# |    total_timesteps      | 460800      |
# | train/                  |             |
# |    approx_kl            | 0.015640978 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.35        |
# |    explained_variance   | -2.14       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0427      |
# |    n_updates            | 6160        |
# |    policy_gradient_loss | 0.00813     |
# |    std                  | 0.00115     |
# |    value_loss           | 3.14e-09    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -0.000218  |
# | time/                   |            |
# |    fps                  | 1165       |
# |    iterations           | 226        |
# |    time_elapsed         | 396        |
# |    total_timesteps      | 462848     |
# | train/                  |            |
# |    approx_kl            | 0.03390172 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.35       |
# |    explained_variance   | -0.452     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00254    |
# |    n_updates            | 6170       |
# |    policy_gradient_loss | 0.0078     |
# |    std                  | 0.00114    |
# |    value_loss           | 4.86e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -0.000216  |
# | time/                   |            |
# |    fps                  | 1165       |
# |    iterations           | 227        |
# |    time_elapsed         | 398        |
# |    total_timesteps      | 464896     |
# | train/                  |            |
# |    approx_kl            | 0.02181029 |
# |    clip_fraction        | 0.142      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.35       |
# |    explained_variance   | -0.766     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00642   |
# |    n_updates            | 6180       |
# |    policy_gradient_loss | 0.00595    |
# |    std                  | 0.00115    |
# |    value_loss           | 2.71e-07   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000215   |
# | time/                   |             |
# |    fps                  | 1165        |
# |    iterations           | 228         |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.015160331 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.34        |
# |    explained_variance   | -5.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00447    |
# |    n_updates            | 6190        |
# |    policy_gradient_loss | 0.00712     |
# |    std                  | 0.00116     |
# |    value_loss           | 4.56e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000213   |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 229         |
# |    time_elapsed         | 402         |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.031307608 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.35        |
# |    explained_variance   | -3.49       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.214       |
# |    n_updates            | 6200        |
# |    policy_gradient_loss | 0.00558     |
# |    std                  | 0.00115     |
# |    value_loss           | 6.33e-09    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000211   |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 230         |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.035560645 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.35        |
# |    explained_variance   | -1.13       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00105    |
# |    n_updates            | 6210        |
# |    policy_gradient_loss | 0.0129      |
# |    std                  | 0.00115     |
# |    value_loss           | 9.27e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000208   |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 231         |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.039184734 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.35        |
# |    explained_variance   | -0.154      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0159     |
# |    n_updates            | 6220        |
# |    policy_gradient_loss | 0.00836     |
# |    std                  | 0.00115     |
# |    value_loss           | 6.3e-09     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000206   |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 232         |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.011282757 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.35        |
# |    explained_variance   | -0.741      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0157     |
# |    n_updates            | 6230        |
# |    policy_gradient_loss | 0.00707     |
# |    std                  | 0.00115     |
# |    value_loss           | 3.55e-09    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000202   |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 233         |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.025724001 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.35        |
# |    explained_variance   | -1.38       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00525    |
# |    n_updates            | 6240        |
# |    policy_gradient_loss | 0.0134      |
# |    std                  | 0.00115     |
# |    value_loss           | 3.26e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | -0.000198   |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 234         |
# |    time_elapsed         | 410         |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.023742696 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.35        |
# |    explained_variance   | 0.0354      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0129      |
# |    n_updates            | 6250        |
# |    policy_gradient_loss | 0.00915     |
# |    std                  | 0.00115     |
# |    value_loss           | 1.75e-08    |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 model.learn(total_timesteps=2000000)
#       3 # Save the trained model
#       4 model.save("ppo_mountain.zip")
#
# File ~\Desktop\Research\MujocoHexapod\.venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~\Desktop\Research\MujocoHexapod\.venv\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File ~\Desktop\Research\MujocoHexapod\.venv\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:178, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     175 with th.no_grad():
#     176     # Convert to pytorch tensor or to TensorDict
#     177     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 178     actions, values, log_probs = self.policy(obs_tensor)
#     179 actions = actions.cpu().numpy()
#     181 # Rescale and perform action
#
# File ~\Desktop\Research\MujocoHexapod\.venv\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\Desktop\Research\MujocoHexapod\.venv\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\Desktop\Research\MujocoHexapod\.venv\Lib\site-packages\stable_baselines3\common\policies.py:654, in ActorCriticPolicy.forward(self, obs, deterministic)
#     652 distribution = self._get_action_dist_from_latent(latent_pi)
#     653 actions = distribution.get_actions(deterministic=deterministic)
# --> 654 log_prob = distribution.log_prob(actions)
#     655 actions = actions.reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#     656 return actions, values, log_prob
#
# File ~\Desktop\Research\MujocoHexapod\.venv\Lib\site-packages\stable_baselines3\common\distributions.py:175, in DiagGaussianDistribution.log_prob(self, actions)
#     167 def log_prob(self, actions: th.Tensor) -> th.Tensor:
#     168     """
#     169     Get the log probabilities of actions according to the distribution.
#     170     Note that you must first call the ``proba_distribution()`` method.
#    (...)
#     173     :return:
#     174     """
# --> 175     log_prob = self.distribution.log_prob(actions)
#     176     return sum_independent_dims(log_prob)
#
# File ~\Desktop\Research\MujocoHexapod\.venv\Lib\site-packages\torch\distributions\normal.py:88, in Normal.log_prob(self, value)
#      81 var = self.scale**2
#      82 log_scale = (
#      83     math.log(self.scale) if isinstance(self.scale, Real) else self.scale.log()
#      84 )
#      85 return (
#      86     -((value - self.loc) ** 2) / (2 * var)
#      87     - log_scale
# ---> 88     - math.log(math.sqrt(2 * math.pi))
#      89 )
#
# KeyboardInterrupt:

# %%
observation, info = env.reset()

XTrain = []
YTrain = []
done = False

x = 0
for i in range(10):
    while not done and x < 900:
        action = model.predict(observation)
        XTrain.append(observation)
        YTrain.append(action[0])
    
        observation, reward, done, _, _ = env.step(action[0])
        x+=1

# %%
print(YTrain)
# Out:
# %%
XTest = []

observation, _ = env.reset()

x=0
while not done and x < 900:
    action = model.predict(observation)
    XTest.append(observation)

    observation, reward, done, _, _ = env.step(action[0])
    x+=1

# %%
def f(X):
    return model.predict(X)[0]

# %%
XTrain_np = np.array(XTrain)
XTest_np = np.array(XTest)

print(XTrain_np)

explainer = shap.KernelExplainer(f, XTrain_np)

shap_values = explainer.shap_values(XTest_np)
print("shap_values =", shap_values)
print("base value =", explainer.expected_value)
# Out:
# Using 900 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
# [[-5.6808591e-01  0.0000000e+00]
#  [-5.6775546e-01  3.3041020e-04]
#  [-5.6709820e-01  6.5723161e-04]
#  ...
#  [-4.9413675e-01  2.8593675e-03]
#  [-4.9149519e-01  2.6415668e-03]
#  [-4.8909953e-01  2.3956678e-03]]
#   0%|          | 0/900 [00:00<?, ?it/s]
# shap_values = [array([[ 0.00264773,  0.00207043],
#        [ 0.00021447, -0.00038384],
#        [ 0.00177412,  0.00133477],
#        ...,
#        [-0.00051288, -0.00024828],
#        [-0.00021971,  0.00014686],
#        [-0.002273  , -0.00179548]])]
# base value = [-0.0018566]

# %%
print(explainer.expected_value[0])
print(shap_values[0])
print(XTest_np[0,:])

shap_values = explainer.shap_values(XTest_np)
# Out:
# -0.0018565987917827443
# [[ 0.00264773  0.00207043]
#  [ 0.00021447 -0.00038384]
#  [ 0.00177412  0.00133477]
#  ...
#  [-0.00051288 -0.00024828]
#  [-0.00021971  0.00014686]
#  [-0.002273   -0.00179548]]
# [-0.59877485  0.        ]
#   0%|          | 0/900 [00:00<?, ?it/s]

# %%
shap.force_plot(explainer.expected_value, shap_values[0], XTest_np, feature_names=["x_pos","vel"])
# Out:
# <div id='iUC5MCWTB30H800P30QGB'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": -0.0018565987917827443, "link": "identity", "featureNames": ["x_pos", "vel"], "explanations": [{"outValue": 0.0008561785798519852, "simIndex": 48.0, "features": {"0": {"effect": 0.001548585939712615, "value": -0.5987748503684998}, "1": {"effect": 0.0011641914319221146, "value": 0.0}}}, {"outValue": -0.003269519656896591, "simIndex": 673.0, "features": {"0": {"effect": -0.0004545055537406986, "value": -0.5982215404510498}, "1": {"effect": -0.0009584153113731483, "value": 0.0005533145158551633}}}, {"outValue": -0.0014762376667931676, "simIndex": 318.0, "features": {"0": {"effect": 0.0003292030311745787, "value": -0.5971125960350037}, "1": {"effect": 5.115809381499802e-05, "value": 0.0011089625768363476}}}, {"outValue": -0.0018971433164551854, "simIndex": 551.0, "features": {"0": {"effect": 0.00030082140855180713, "value": -0.5954535603523254}, "1": {"effect": -0.00034136593322424825, "value": 0.0016590137965977192}}}, {"outValue": 0.001440715976059437, "simIndex": 79.0, "features": {"0": {"eff